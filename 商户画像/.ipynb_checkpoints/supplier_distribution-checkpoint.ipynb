# %% [markdown]
# # 商户画像，数据分布

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#读入数据 
supplier_data = pd.read_csv('supplier_photo.csv', index_col = 1)
del supplier_data['create_dt']
supplier_data.head(10)
# Out:
#              city_id  fee_sum  fee_per_user  order_shuliang  active_day  \
# supplier_id
# 28                 1        2      1.000000               2           1
# 125                1    11705     25.172043             465          18
# 148                1     6632     33.326633             199          26
# 156                1    20185     34.982669             577          26
# 193                1     8813     32.640741             270          25
# 216                1    17697     23.882591             741          13
# 222                1      523     30.764706              17           9
# 239                1    10079     38.616858             261          25
# 247                1     1934     32.779661              59          18
# 262                1     8836     27.962025             316          23
#
#              active_lv  supplier_first_date
# supplier_id
# 28              0.0333                   28
# 125             0.6000                   18
# ...

# %%
supplier_data.describe()
# Out:
#             city_id        fee_sum  fee_per_user  order_shuliang  \
# count  46610.000000   46610.000000  46610.000000    46610.000000
# mean      10.931903    8469.155583     30.918917      290.754709
# std        8.504095   11946.980740     11.052609      414.469045
# min        1.000000       0.100000      0.100000        1.000000
# 25%        3.000000    1387.000000     26.215510       45.000000
# 50%        9.000000    4332.700000     29.080109      145.000000
# 75%       17.000000   10666.875000     32.692308      365.000000
# max       40.000000  223884.000000   1076.000000     7197.000000
#
#          active_day     active_lv  supplier_first_date
# count  46610.000000  46610.000000         46610.000000
# mean      15.115383      0.503846            22.205128
# std        9.274886      0.309165            19.202376
# min        1.000000      0.033300             1.000000
# 25%        7.000000      0.233300            10.000000
# ...

# %%
supplier_data.corr()
# Out:
#                       city_id   fee_sum  fee_per_user  order_shuliang  \
# city_id              1.000000 -0.031283     -0.026494       -0.030108
# fee_sum             -0.031283  1.000000     -0.070344        0.988118
# fee_per_user        -0.026494 -0.070344      1.000000       -0.113661
# order_shuliang      -0.030108  0.988118     -0.113661        1.000000
# active_day          -0.148835  0.552956     -0.088981        0.548162
# active_lv           -0.148837  0.552956     -0.088981        0.548162
# supplier_first_date -0.070116  0.435454     -0.001882        0.428715
#
#                      active_day  active_lv  supplier_first_date
# city_id               -0.148835  -0.148837            -0.070116
# fee_sum                0.552956   0.552956             0.435454
# fee_per_user          -0.088981  -0.088981            -0.001882
# order_shuliang         0.548162   0.548162             0.428715
# active_day             1.000000   1.000000             0.676218
# ...

# %% [markdown]
# # 下面展示客单价

# %%
plt.plot(supplier_data['fee_per_user'],'ko--')
plt.show()

# %%
supplier_data[supplier_data.fee_per_user > 200]
# Out:
#              city_id  fee_sum  fee_per_user  order_shuliang  active_day  \
# supplier_id
# 27698              5    486.0    486.000000               1           1
# 43388              8    230.0    230.000000               1           1
# 67198              9    298.0    298.000000               1           1
# 82295             19    312.0    312.000000               1           1
# 91328             11    298.0    298.000000               1           1
# 115382             3   1076.0   1076.000000               1           1
# 119817             2    370.0    370.000000               1           1
# 120165            11   1295.0    215.833333               6           5
# 132765            12    390.0    390.000000               1           1
# 140951            19    276.0    276.000000               1           1
# 171598            19    881.0    220.250000               4           4
# 213121            21    270.5    270.500000               1           1
#
# ...

# %%
plt.plot(supplier_data[supplier_data.fee_per_user > 100]['fee_per_user'],'ko--')
plt.show()

# %%
plt.plot(supplier_data[supplier_data.fee_per_user <= 100]['fee_per_user'],'ko--')
plt.show()

# %%
plt.plot(supplier_data[supplier_data.fee_per_user < 20]['fee_per_user'],'ko--')
plt.show()

# %%
plt.plot(supplier_data[(supplier_data.fee_per_user >= 20) & (supplier_data.fee_per_user <= 100)]['fee_per_user'],'ko--')
plt.show()

# %%
plt.bar(np.array(),supplier_data['fee_per_user']）

# %%
plt.hist(supplier_data['fee_per_user'], 50, normed=1, facecolor='green', alpha=0.75)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-cac8860e6869> in <module>()
# ----> 1 plt.hist(supplier_data['fee_per_user'], 50, normed=1, facecolor='green', alpha=0.75)
#       2 plt.show()
#
# c:\python27\lib\site-packages\matplotlib\pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2956                       histtype=histtype, align=align, orientation=orientation,
#    2957                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2958                       stacked=stacked, data=data, **kwargs)
#    2959     finally:
#    2960         ax.hold(washold)
#
# c:\python27\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
supplier_data.ix[:,'order_shuliang'].value_counts().plot(kind='bar',title= 'order_shuliang')

# %%
supplier_data.ix[:,'active_day'].value_counts().plot(kind='bar',title= 'active_day')

# %%
supplier_data[supplier_data.city_id == 19].ix[:,'active_day'].value_counts().plot(kind='bar',title= 'active_day')

# %%
supplier_data[supplier_data.city_id == 1].ix[:,'active_day'].value_counts().plot(kind='bar',title= 'active_day')

# %%
supplier_data[supplier_data.city_id == 1].ix[:,'supplier_first_date'].value_counts().plot(kind='bar',title= 'supplier_first_date')

# %%
supplier_data[supplier_data.city_id == 19].ix[:,'supplier_first_date'].value_counts().plot(kind='bar',title= 'supplier_first_date')

# %%
paidan_data.iloc[:,0].value_counts().plot(kind='bar',title= paidan_data.columns[0])
pclass_xt = pd.crosstab(paidan_data.iloc[:,0], paidan_data.iloc[:,76])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True)


pclass_xt = pd.crosstab(paidan_pro['pro'], paidan_pro['label'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
print pclass_xt 
print pclass_xt_pct

plt.hist(paidan_pro['pro'])
plt.show()
pclass_xt.plot(kind = 'bar',stacked = True)
pclass_xt_pct.plot(kind='bar', stacked=True)
